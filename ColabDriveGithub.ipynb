# %%
from google.colab import drive

# %%
ROOT = '/content/drive'
drive.mount(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
HOME = ROOT + '/My Drive/Colab Notebooks/dw_matrix'
HOME
# Out:
# '/content/drive/My Drive/Colab Notebooks/dw_matrix'

# %%
# !mkdir -p "{HOME}"

# %%
ls
# Out:
# drive/  sample_data/

# %%
GITHUB_TOKEN='907d52751511243a288b2024f1dc6deb8692267d'
GITHUB_URL = 'https://{0}@github.com/trexml/dw_matrix.git'.format(GITHUB_TOKEN)
GITHUB_URL
# Out:
# 'https://907d52751511243a288b2024f1dc6deb8692267d@github.com/trexml/dw_matrix.git'

# %%
# !git clone {GITHUB_URL}
# Out:
# Cloning into 'dw_matrix'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.

# %%
ls
# Out:
# HelloGithub.ipynb  LICENSE  README.md

# %%
# !git add HelloGithub.ipynb

# %%
# !git config --global user.email "akuzka.pivotal@gmail.com"
# !git config --global user.name "Adam Kuzka"

# %%
# !git commit -m "modify notebook"
# Out:
# [master 35c1564] modify notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite HelloGithub.ipynb (81%)

# %%
# !git push -u origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 812 bytes | 270.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/trexml/dw_matrix.git
#    569628c..35c1564  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
ls
# Out:
# HelloGithub.ipynb  LICENSE  README.md
